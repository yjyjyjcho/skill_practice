# %%
import requests
from bs4 import BeautifulSoup

keyword = '빅데이터'
url = 'https://search.naver.com/'
r = requests(url)
bs = BeautifulSoup(r.text, 'lxml')

# %%
https://search.naver.com/search.naver?sm=top_hty&fbm=1&ie=utf8&query=%EB%B9%85%EB%8D%B0%EC%9D%B4%ED%84%B0 #베이스64식 인코딩

# %%
from google.colab import drive
drive.mount('/content/drive')
