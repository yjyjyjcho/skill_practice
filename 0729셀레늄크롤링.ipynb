# %%
pip install selenium
# Out:
# ...
#      |████████████████████████████████| 911kB 2.7MB/s
# ...

# %%
#하위 태그선택

# items = soup.select('html  > title')

items = soup.select('html  title')
for item in items:
  print(item.get_text())
